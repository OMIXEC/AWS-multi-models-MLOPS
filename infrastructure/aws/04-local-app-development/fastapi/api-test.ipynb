# %% [markdown]
# ## GET Requests

# %%
import requests

# %%
url = "http://127.0.0.1:8502/get_sentiment_v2/this%20is%20dummy%20text/172.162.021.21?user_id=email%40gmail.com"
response = requests.get(url=url)

response.json()
# Out:
# {'ip': '172.162.021.21',
#  'text': 'this is dummy text',
#  'sentiment': 'positive',
#  'user_id': 'email@gmail.com'}

# %%
url = "http://127.0.0.1:8502/get_sentiment_v2/this%20is%20some%20text/172.12.121.21"
params = {
    "user_id": "email@email.com"
}

response = requests.get(url=url, params=params)

response.json()
# Out:
# {'ip': '172.12.121.21',
#  'text': 'this is some text',
#  'sentiment': 'positive',
#  'user_id': 'email@email.com'}

# %% [markdown]
# ## POST Requests

# %%
# curl -X 'POST' 'http://127.0.0.1:8000/get_twitter_sentiment?text=This%20feels%20really%20good&ip=213.23.34.1&user_id=email%40email.com' -H 'accept: application/json' -d ''

# %%
import requests

url = "http://127.0.0.1:8502/get_twitter_sentiment"

params = {
    "text": "This really feels weird",
    "ip": "172.32.123.12",
    "user_id": "email@email.com"
}

headers = {
    "accept": "application/json"
}

response = requests.post(url=url, headers=headers, params=params)

response.json()
# Out:
# {'ip': '172.32.123.12',
#  'text': 'This really feels weird',
#  'sentiment': 'normal',
#  'user_id': 'email@email.com'}

# %% [markdown]
# ## Upload Image to S3

# %%
from scripts import s3

# %%
s3.upload_image_to_s3("images/omixec.png")
# Out:
# 'https://mlops-multi-models.s3.amazonaws.com/ml-images/omixec.png?AWSAccessKeyId=AKIASVQKHL5BOU74F5FA&Signature=dohab6nFe7QRDXvqxsoOu1LlTqo%3D&Expires=1772669560'

# %% [markdown]
# ## ML API Testing

# %%
import requests
import json

url = "http://app-lb-2030153789.us-east-1.elb.amazonaws.com/api/v1/pose_classifier"
headers = {
  'Content-Type': 'application/json'
}

payload = json.dumps({
  "url": [
    "https://images.pexels.com/photos/1755385/pexels-photo-1755385.jpeg"
  ],
  "user_id": "email@email.com"
})

for i in range(1000):
  response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/dev/github/Production-projects/Cloud/aws/ml-ops-and-model-deployment-on-aws-main/venv/lib/python3.11/site-packages/urllib3/connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File ~/dev/github/Production-projects/Cloud/aws/ml-ops-and-model-deployment-on-aws-main/venv/lib/python3.11/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ...
