# %% [markdown]
# # Google Cloud Storage (GCS) Tutorial in Python

# %%
# Download requirements.txt or install indvidually google-cloud-storage
# !pip install google-cloud-storage

# %%
! export GCP_PROJECT_ID="YOUR-PROJECT-ID"
! export GCP_REGION="YOUR-GCP-REGION"
! export GCS_BUCKET_NAME="YOUR-BUCKET-NAME-$(date +%s)" # Adds timestamp for uniqueness

# IAM & Security (Service Account Path)
! export GOOGLE_APPLICATION_CREDENTIALS="/path/to/your/service-account-key.json"

# Verify they are set
! echo "Project is set to: $GCP_PROJECT_ID"

# %%
from google.cloud import storage

client = storage.Client()
bucket_name = 'multi-models'

def create_bucket():
    bucket = client.create_bucket(bucket_name)
    print(f'Bucket {bucket.name} created.')

create_bucket()

# %%
def upload_blob(source_file_name, destination_blob_name):
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)
    blob.upload_from_filename(source_file_name)
    print(f'File {source_file_name} uploaded.')

upload_blob('data/index.html', 'somefile.html')

# %%
def list_blobs():
    blobs = client.list_blobs(bucket_name)
    for blob in blobs:
        print(blob.name)

list_blobs()

# %%
def download_blob(source_blob_name, destination_file_name):
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(source_blob_name)
    blob.download_to_filename(destination_file_name)
    print('Downloaded.')

download_blob('somefile.html', 'data_download/index.html')
