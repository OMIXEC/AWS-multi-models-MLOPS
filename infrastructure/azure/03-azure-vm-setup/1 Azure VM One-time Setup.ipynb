# %% [markdown]
# # Azure Virtual Machine One-time Setup
# This notebook provisions an Azure VM and NSG rules.
#
# Note: Make sure you defined your environment and have downloaded the requirments file before you running the notebook

# %%
# Optional in case you did not download the deopendencies.
#!pip install azure-mgmt-compute azure-identity azure-mgmt-network azure-mgmt-resource

# %%
from azure.identity import DefaultAzureCredential
from azure.mgmt.compute import ComputeManagementClient
from azure.mgmt.network import NetworkManagementClient
from azure.mgmt.resource import ResourceManagementClient

credential = DefaultAzureCredential()
subscription_id = 'your-subscription-id'

resource_client = ResourceManagementClient(credential, subscription_id)
compute_client = ComputeManagementClient(credential, subscription_id)
network_client = NetworkManagementClient(credential, subscription_id)

# %%
resource_group_name = 'mlops-rg'
location = 'eastus'

# Create Resource Group
rg_result = resource_client.resource_groups.create_or_update(resource_group_name, {'location': location})
print(f'Provisioned resource group {rg_result.name}')

# %%
# Create NSG with rules for 22, 80, 8501, 8502
def create_nsg():
    pass # NSG Logic here
